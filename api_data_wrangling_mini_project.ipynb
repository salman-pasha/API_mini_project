# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = ''

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# !pip install requests

# %%
# First, import the relevant modules
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url ="https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?start_date=2020-06-17&end_date=2020-06-17&api_key=" + API_KEY
r = requests.get(url)
json_data = r.json()

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# dataset:  {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-06-04) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-06-18T22:16:17.493Z', 'newest_available_date': '2020-06-18', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2020-06-17', 'end_date': '2020-06-17', 'data': [['2020-06-17', 90.55, 92.15, 89.7, 91.45, None, 149331.0, 13655800.2, None, None, None]], 'collapse': None, 'order': None, 'database_id': 6129}

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
url ="https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?start_date=2017-01-01&end_date=2017-12-31&api_key=" + API_KEY
r = requests.get(url)
json_data = r.json()

# %%
print(type(json_data))
data = json_data['dataset']['data']
# Out:
# <class 'dict'>

# %%
openingpriceslist = []
for k in data:
    if k[1] is not None:
        openingpriceslist.append(k[1])
    
openingpriceslist
# Out:
# [51.76,
#  51.65,
#  51.45,
#  51.05,
#  51.16,
#  51.88,
#  52.73,
#  52.37,
#  52.7,
#  53.11,
#  52.64,
#  52.29,
#  52.28,
#  51.5,
#  50.89,
#  50.8,
#  51.21,
#  49.5,
#  49.52,
#  48.64,
#  49.64,
#  49.09,
#  49.13,
#  49.11,
#  48.8,
#  48.4,
#  47.25,
#  46.57,
#  47.03,
#  47.09,
#  47.98,
#  48.4,
#  48.38,
#  47.3,
#  47.65,
#  46.42,
#  46.16,
#  45.81,
#  45.0,
#  45.88,
#  46.29,
#  46.53,
#  45.48,
#  45.2,
#  45.01,
#  45.16,
#  44.9,
#  45.08,
#  45.72,
#  46.01,
#  45.8,
#  45.61,
#  45.5,
#  45.58,
#  45.97,
#  45.64,
#  46.2,
#  46.19,
#  46.01,
#  45.36,
#  44.51,
#  43.58,
#  42.0,
#  42.35,
#  42.3,
#  42.3,
#  41.48,
#  42.29,
#  42.54,
#  42.65,
#  42.5,
#  42.29,
#  42.35,
#  42.49,
#  43.21,
#  42.81,
#  42.7,
#  43.0,
#  42.66,
#  43.0,
#  42.38,
#  42.16,
#  42.0,
#  42.0,
#  41.71,
#  42.11,
#  42.64,
#  42.72,
#  42.82,
#  42.46,
#  42.42,
#  42.28,
#  41.88,
#  42.4,
#  42.53,
#  42.12,
#  41.3,
#  41.73,
#  43.5,
#  44.9,
#  45.85,
#  45.13,
# ...

# %%
highest_opening_price = max(openingpriceslist)
lowest_opening_price = min(openingpriceslist)
print("highest opening prices: " + str(highest_opening_price))
print("lowest opening prices: " + str(lowest_opening_price))
# Out:
# highest opening prices: 53.11
# lowest opening prices: 34.0

# %%
len(openingpriceslist)
# Out:
# 252

# %%
largestChangeInADayList = []
for k in data:
    if k[2] is not None:
        if k[3] is not None:
            largestChangeInADayList.append(k[2]-k[3])         
largestChangeInADayList
# Out:
# [0.4899999999999949,
#  0.39000000000000057,
#  1.1300000000000026,
#  0.5799999999999983,
#  0.6200000000000045,
#  0.8399999999999963,
#  1.6599999999999966,
#  1.1400000000000006,
#  1.0600000000000023,
#  1.3900000000000006,
#  0.8700000000000045,
#  1.2800000000000011,
#  1.1900000000000048,
#  1.5499999999999972,
#  0.6599999999999966,
#  0.7199999999999989,
#  0.980000000000004,
#  1.7299999999999969,
#  1.3200000000000003,
#  1.5600000000000023,
#  0.9399999999999977,
#  0.8599999999999994,
#  0.769999999999996,
#  0.5399999999999991,
#  1.009999999999998,
#  1.2199999999999989,
#  1.8100000000000023,
#  0.8400000000000034,
#  0.3500000000000014,
#  0.6799999999999997,
#  1.259999999999998,
#  1.0599999999999952,
#  0.8500000000000014,
#  1.730000000000004,
#  0.9699999999999989,
#  1.2999999999999972,
#  0.4899999999999949,
#  0.3300000000000054,
#  1.2100000000000009,
#  0.8800000000000026,
#  0.5799999999999983,
#  1.0399999999999991,
#  0.9600000000000009,
#  0.5,
# ...

# %%
largest_change_in_a_day = max(largestChangeInADayList)
print("Largest change in any one day : " + str(largest_change_in_a_day))
# Out:
# Largest change in any one day : 2.8100000000000023

# %%
len(data)
# Out:
# 255

# %%
closingPriceList = []
for k in data:
    if k[4] is not None:
        closingPriceList.append(k[4])
maxClosePrice = max(closingPriceList)
minClosePrice = min(closingPriceList)
print("largest change between any two days: " + str(maxClosePrice - minClosePrice))
# Out:
# largest change between any two days: 19.03

# %%
dailyTradeUnits = []
for k in data:
    if k[6] is not None:
        dailyTradeUnits.append(k[6])
dailyTradeUnits
# Out:
# [34640.0,
#  40660.0,
#  57452.0,
#  71165.0,
#  120649.0,
#  50587.0,
#  137313.0,
#  129733.0,
#  204080.0,
#  132981.0,
#  128434.0,
#  87911.0,
#  71817.0,
#  109157.0,
#  48123.0,
#  88730.0,
#  83023.0,
#  94385.0,
#  101733.0,
#  123019.0,
#  67342.0,
#  42669.0,
#  102180.0,
#  50350.0,
#  38834.0,
#  91142.0,
#  78502.0,
#  97252.0,
#  54107.0,
#  89373.0,
#  67593.0,
#  67672.0,
#  76286.0,
#  90245.0,
#  120268.0,
#  94195.0,
#  48152.0,
#  60716.0,
#  56911.0,
#  37958.0,
#  56319.0,
#  56245.0,
#  74472.0,
#  56319.0,
#  47730.0,
#  43042.0,
#  43375.0,
#  55707.0,
#  59991.0,
#  45263.0,
#  65837.0,
#  49246.0,
#  43362.0,
#  49180.0,
#  69455.0,
#  65860.0,
#  44059.0,
#  66760.0,
#  94804.0,
#  115706.0,
#  95313.0,
#  99821.0,
#  157234.0,
#  76600.0,
#  51321.0,
#  56224.0,
#  79955.0,
#  105194.0,
#  57838.0,
#  65546.0,
#  44037.0,
#  107144.0,
#  65157.0,
#  68801.0,
#  52828.0,
#  103273.0,
#  59881.0,
#  64320.0,
#  71006.0,
#  66351.0,
#  105288.0,
# ...

# %%
avg_traded_volumes = sum(dailyTradeUnits)/len(dailyTradeUnits)

# %%
print("average daily trading volume during this year: "+ str(avg_traded_volumes))
# Out:
# average daily trading volume during this year: 89124.33725490196
